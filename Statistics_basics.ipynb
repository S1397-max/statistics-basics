# %% [markdown]
# 1. Data is classified into two broad categories:
#
# Qualitative Data: Describes attributes or characteristics that cannot be measured numerically. It is divided into:
#
# Nominal Data: Categories without any inherent order. Examples include eye color (blue, brown, green) or types of pets (dog, cat, bird).
#
# Ordinal Data: Categories that have an inherent order but the differences between them may not be measurable. Examples include educational levels (high school, undergraduate, postgraduate) or satisfaction ratings (poor, average, good, excellent).
#
# Quantitative Data: Represents numerical values and can be measured objectively. It is divided into:
#
# Interval Data: Data with equal intervals but no true zero point. Example: Temperature in Celsius, where 0°C does not indicate the absence of temperature.
#
# Ratio Data: Data with equal intervals and a true zero point. Example: Height or weight, where 0 means the absence of height or weight.
#
# 2. Central tendency refers to the statistical measures that describe the center of a facts set.
#
# Mean (Arithmetic Average): Sum of all values divided via the entire quantity of observations. Used whilst information is typically allotted.
#
# Example: Average month-to-month salary in a organisation.
#
# Limitations: Susceptible to severe values (outliers).
#
# Median: Middle price whilst data is organized in ascending order. Useful for skewed distributions.
#
# Example: Median home charge in a town, which avoids distortion by means of some extremely luxurious houses.
#
# Mode: The most regularly happening cost in a dataset. Useful for specific information.
#
# Example: Most commonplace shoe length sold in a store.
#
# 3. Dispersion measures how spread out values are within a dataset.
#
# Variance: The average of the squared differences from the mean. A higher variance indicates greater spread.
#
# Formula:
#
# 𝜎
# 2
# =
# ∑
# (
# 𝑥
# 𝑖
# −
# 𝑥
# ˉ
# )
# 2
# 𝑛
#
#
# Example: Comparing the variability in exam scores between two classes.
#
# Standard Deviation: Square root of variance. It provides a measure of data spread in the same units as the original values.
#
# Formula:
#
# 𝜎
# =
# 𝜎
# 2
#
#
# Example: Understanding volatility in stock prices.
#
# 4. A container plot graphically represents the distribution of numerical records based totally on 5-number summary:
#
# Minimum: Smallest cost.
#
# Q1 (First Quartile): 25th percentile.
#
# Median: Middle cost.
#
# Q3 (Third Quartile): 75th percentile.
#
# Maximum: Largest fee.
#
# Box plots help detect outliers and understand facts skewness.
#
# 5. Random sampling guarantees a consultant subset of a larger population to make statistical inferences.
#
# Simple Random Sampling (SRS): Every character has an identical threat of being selected.
#
# Stratified Sampling: Population is split into subgroups and sampled proportionally.
#
# Systematic Sampling: Selection at normal durations.
#
# Cluster Sampling: Groups rather than people are sampled.
#
# Random sampling reduces bias and enhances the validity of statistical conclusions.
#
#
# 6. Skewness measures the asymmetry of a distribution.
#
# Positive Skew (Right-Skewed): Tail extends to the proper; imply > median.
#
# Negative Skew (Left-Skewed): Tail extends to the left; suggest < median.
#
# Zero Skew: Symmetric distribution wherein imply = median.
#
# Skewness influences the selection of important tendency measures. In right-skewed records, the median is desired over the imply to lessen distortion.
#
# 7. The interquartile range (IQR) is the difference between the third and first quartile:
#
# 𝐼
# 𝑄
# 𝑅
# =
# 𝑄
# 3
# −
# 𝑄
# 1
#
# To detect outliers:
#
# Lower Bound:
#
# 𝑄
# 1
# −
# 1.5
# ×
# 𝐼
# 𝑄
# 𝑅
#
# Upper Bound:
#
# 𝑄
# 3
# +
# 1.5
# ×
# 𝐼
# 𝑄
# 𝑅
#
# Outliers lie beyond these thresholds. They indicate extreme deviations in data.
#
# 8. Binomial distribution applies under these conditions:
#
# Fixed number of trials (
# 𝑛
# ).
#
# Two possible outcomes (success or failure).
#
# Probability remains constant (
# 𝑝
# ).
#
# Independent trials.
#
# Example: Probability of getting exactly 3 heads in 5 coin flips.
#
# 9. A everyday distribution follows a symmetrical bell-fashioned curve.
#
# Empirical Rule:
#
# 68% of values fall within 1 preferred deviation of the imply.
#
# 95% within 2 trendy deviations.
#
# Ninety nine.7% within three wellknown deviations.
#
# Example: Heights of adults usually follow a everyday distribution.
#
#
# 10. Poisson distribution models rare events occurring over a fixed interval.
#
# Example: A customer service center receives 5 calls per hour on average. What is the probability of receiving 8 calls in an hour?
#
# Poisson formula:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝑒
# −
# 𝜆
# 𝜆
# 𝑘
# 𝑘
# !
# Where:
#
# 𝜆
# =
# 5
#  (average rate)
#
# 𝑘
# =
# 8
#
# Solving gives the probability of 8 calls occurring in one hour.
#
# 11. A random variable is a variable whose values rely upon threat.
#
# Discrete Random Variables: Have countable values.
#
# Example: Number of defective products in a batch.
#
# Continuous Random Variables: Can take any cost within a range.
#
# Example: The specific time a consumer waits for carrier.
#
# 12. Covariance and correlation measure the relationship between two variables.
#
# Covariance Formula:
#
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# =
# ∑
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# 𝑛
# Positive covariance: Variables move in the same direction.
#
# Negative covariance: Variables move in opposite directions.
#
# Correlation Formula:
#
# 𝑟
# =
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# 𝜎
# 𝑋
# 𝜎
# 𝑌
# Value between -1 and 1: Measures strength of relationship.
#
# Example dataset:
#
# Study hours: [2, 4, 6, 8, 10]
#
# Exam scores: [50, 60, 70, 80, 90]
#
# Calculating correlation gives r ≈ 0.98, indicating a strong positive relationship.
